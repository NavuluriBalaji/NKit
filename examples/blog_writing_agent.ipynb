# %% [markdown]
# # Blog Writing Agent with NKit\n
# \n
# This notebook demonstrates how to use the NKit framework to build a blog writing agent using Program-of-Thought (PoT) reasoning.

# %%
import sys\n
import os\n
import asyncio\n
import json\n
\n
# Add NKit to path if running from examples\n
sys.path.insert(0, os.path.dirname(os.path.abspath("..\")))\n
\n
from NKit.tools import ToolRegistry, Tool\n
from NKit.planner import ThoughtPlanner\n
from NKit.executor import ThoughtExecutor\n
from NKit.agent import Agent\n
\n
print("NKit modules imported successfully")

# %% [markdown]
# ## Define Tools\n
# Agents in NKit use tools. Here we define a simple registry.

# %%
def content_search(topic):\n
    return f"Found interesting facts about {topic}"\n
\n
registry = ToolRegistry()\n
registry.register(Tool("search", content_search, "Searches for content on a topic"))\n
print("Tools registered")
